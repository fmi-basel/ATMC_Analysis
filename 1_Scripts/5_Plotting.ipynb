# %% [markdown]
# # Imports

# %%
import seaborn as sns
import anndata

# %% [markdown]
# # User input

# %%
load_dir = "PATH TO OUTPUT FROM 4_DM" # Path to .h5ad file containing the AnnData object.

fig_param = {"axes.spines.right": False,
                  "axes.spines.top": False,
                  "axes.spines.left": True,
                  "axes.spines.bottom": True,
                  "pdf.fonttype": 42,
                  "font.size": 6,
                  "axes.labelsize": 6,
                  "axes.titlesize": 8,
                  "xtick.labelsize": 6,
                  "ytick.labelsize": 6,
                  "legend.fontsize": 6}

sns.set_theme(rc = fig_param, style = "ticks")

# %% [markdown]
# # Load & misc

# %%
ad = anndata.read_h5ad(load_dir)

# %% [markdown]
# # WORK IN PROGRESS
